# %% [markdown]
# # EDA with Pandas - Cumulative Lab
#
# ## Introduction
#
# In this section, you've learned a lot about importing, cleaning up, analyzing (using descriptive statistics) and visualizing data. In this cumulative lab, you'll get a chance to practice all of these skills with the Ames Housing dataset, which contains information about home sales in Ames, Iowa between 2006 and 2010.
#
# ## Objectives
#
# You will be able to:
#
# * Practice loading data with pandas
# * Practice calculating measures of centrality and dispersion with pandas
# * Practice creating subsets of data with pandas
# * Practice using data visualizations to explore data, and interpreting those visualizations
# * Perform a full exploratory data analysis process to gain insight about a dataset

# %% [markdown]
# ## Your Task: Explore the Ames Housing Dataset with Pandas
#
# ![aerial photo of a neighborhood](images/neighborhood_aerial.jpg)
#
# Photo by <a href="https://unsplash.com/@mattdonders?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Matt Donders</a> on <a href="/@mattdonders?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
#
# Each record (row) in this dataset represents a home that was sold in Ames, IA.
#
# Each feature (column) in this dataset is some attribute of that home sale. You can view the file `data/data_description.txt` in this repository for a full explanation of all variables in this dataset — 80 columns in total.
#
# We are going to focus on the following features:
#
# **SalePrice**: `Sale price of the house in dollars`
#
# **TotRmsAbvGrd**: `Total rooms above grade (does not include bathrooms)`
#
# **OverallCond**: `Rates the overall condition of the house`
# ```
#        10	Very Excellent
#        9	 Excellent
#        8	 Very Good
#        7	 Good
#        6	 Above Average
#        5	 Average
#        4	 Below Average
#        3	 Fair
#        2	 Poor
#        1	 Very Poor
# ```
#
# **YrSold**: `Year Sold (YYYY)`
#
# **YearBuilt**: `Original construction date`
#
# **LandSlope**: `Slope of property`
# ```
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
# ```

# %% [markdown]
# ### Requirements
#
# In this lab you will use your data munging and visualization skills to conduct an exploratory analysis of the dataset.
#
# #### 1. Load the Dataset with Pandas
#
# Import pandas with the standard alias `pd` and load the data into a dataframe with the standard name `df`.
#
# #### 2. Explore Data Distributions
#
# Produce summary statistics, visualizations, and interpretive text describing the distributions of `SalePrice`, `TotRmsAbvGrd`, and `OverallCond`.
#
# #### 3. Explore Differences between Subsets
#
# Separate the data into subsets based on `OverallCond`, then demonstrate how this split impacts the distribution of `SalePrice`.
#
# #### 4. Explore Correlations
#
# Find the features that have the strongest positive and negative correlations with `SalePrice`, and produce plots representing these relationships.
#
# #### 5. Engineer and Explore a New Feature
#
# Create a new feature `Age`, which represents the difference between the year sold and the year built, and plot the relationship between the age and sale price.

# %% [markdown]
# ## Data Analytics Report
#
# ### Research Questions
#     1.  To find out the average sales prices of houses in Ames between 2006 and 2010
#     2.  To find out the number of total rooms above average.
#     3.  To find out the overall condition with the highest number of houses.
#     4.  To find out the features that have the strongest positive and negative correlation with SalePrice.

# %% [markdown]
# ### Data Analysis Architecture
# >

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. Load the Dataset with Pandas
#
# In the cell below, import:
# * `pandas` with the standard alias `pd`
# * `matplotlib.pyplot` with the standard alias `plt`
#
# And set `%matplotlib inline` so the graphs will display immediately below the cell that creates them.

# %%
# Data Ingestion/Loading using Pandas
import pandas as pd  #Importing pandas for data manipulation
import matplotlib.pyplot as plt #Importing Matplotlib.pylot for visualization
# %matplotlib inline

# %% [markdown]
# Now, use pandas to open the file located at `data/ames.csv` ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)). Specify the argument `index_col=0` in order to avoid creating an extra `Id` column. Name the resulting dataframe `df`.

# %%
# Data Ingestion - Reading the 'Ames CSV'from the data folder and returns a dataframe.
df = pd.read_csv('data/ames.csv', index_col= 0)
df.head(2)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
#
# [2 rows x 80 columns]

# %% [markdown]
# The following code checks that you loaded the data correctly:

# %%
# Run this cell without changes

# Check that df is a dataframe
assert type(df) == pd.DataFrame

# Check that there are the correct number of rows
assert df.shape[0] == 1460

# Check that there are the correct number of columns
# (if this crashes, make sure you specified `index_col=0`)
assert df.shape[1] == 80

# %% [markdown]
# Inspect the contents of the dataframe:

# %%
# Run this cell without changes
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
# Run this cell without changes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# ## 2. Explore Data Distributions
#
# Write code to produce histograms showing the distributions of `SalePrice`, `TotRmsAbvGrd`, and `OverallCond`.
#
# Each histogram should have appropriate title and axes labels, as well as a black vertical line indicating the mean of the dataset. See the documentation for [plotting histograms](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hist.html), [customizing axes](https://matplotlib.org/stable/api/axes_api.html#axis-labels-title-and-legend), and [plotting vertical lines](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.axvline.html#matplotlib.axes.Axes.axvline) as needed.

# %% [markdown]
# ### Sale Price
#
# In the cell below, produce a histogram for `SalePrice`.

# %%
#Understanding the distribution of salesprice column with basic measures of central tendacy.
df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
# df.columns

# %%
# Visualizing a histogram for Saleprice
#Filters data to only display Salesprice column
salesprice = df.loc[:, 'SalePrice'] 
#Plot the histogram
plt.hist(salesprice, bins= 15, edgecolor = 'black', color="#00C8AD")

plt.xlabel('SalePrice')
plt.ylabel('Frequency of Values')
plt.title('Distribution of Sales Price')
plt.show()
# df.head()

# %%
# Alternative method to plot histogram
# df['SalePrice'].plot(kind='hist')

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# The below code computes the salesprice, rounds off the values to three decimal places and prints out the values.

# Salesprice Mean
SalesPrice_mean = round(salesprice.mean(),4) 
# Salesprice median
SalesPrice_median = round(salesprice.median(),4)
# SalesPrice Standard deviation
SalesPrice_Stdv = round(salesprice.std(),4)
# Prints out the results
print("SalesPrice Mean :", SalesPrice_mean)
print("SalesPrice Median :", SalesPrice_median)
print("SalesPrice Standard Deviation:", SalesPrice_Stdv)
# Out:
# SalesPrice Mean : 180921.1959
# SalesPrice Median : 163000.0
# SalesPrice Standard Deviation: 79442.5029

# %% [markdown]
# In the cell below, interpret the above information.

# %% [markdown]
# ### Data Finding Interpretation
# - **Mean** , we have a significant mean of $180,921.1959 which is a reflcetion of the average sales price of houses in Ames between 2006 and 2010.
# - **Median** , The median sales price of houses in Ames is $163,000, which gives a probable house price at any given point between 2006 and 2010.
# - **Standard Deviation** , The standard deviation indicates that the houses in Ames vary with a significant amount of $79,442.5 from the mean. That is, the prices can be either higher or lower by $79,442.5 from the mean.
#
# **Additional Interpretation** The mean salesprice of $180,921.1959 is greater than the median sales price of $163,000 which indicates that the data is right-skewed.

# %% [markdown]
# ### Total Rooms Above Grade
#
# In the cell below, produce a histogram for `TotRmsAbvGrd`.

# %%
# Histogram for Total Rooms Above Grade
#Filters data to only display Salesprice column
TotRmsAbvGrd = df.loc[:, 'TotRmsAbvGrd'] 
#Plot the histogram
plt.hist(TotRmsAbvGrd, bins= 15, edgecolor = 'black')

plt.xlabel('Total Rooms Above Grade')
plt.ylabel('Frequency of Values')
plt.title('Distribution of Total Rooms Above Grade')
plt.show()

# # Plot Kde in future for further insightful analysis. 
# df['TotRmsAbvGrd'].plot(kind='kde')
# plt.xlabel('Total Rooms Above Grade')
# plt.ylabel('Frequency of Values')
# plt.title('Distribution of Total Rooms Above Grade')
# plt.show()

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# The below code computes the Total rooms above grade, rounds off the values to three decimal places and prints out the values.
# Salesprice Mean
TotRmsAbvGrd_mean = round(TotRmsAbvGrd.mean(),4) 
# Salesprice median
TotRmsAbvGrd_median = round(TotRmsAbvGrd.median(),4)
# SalesPrice Standard deviation
TotRmsAbvGrd_Stdv = round(TotRmsAbvGrd.std(),4)
# Prints out the results
print(" Mean :", TotRmsAbvGrd_mean)
print(" Median :", TotRmsAbvGrd_median)
print(" Standard Deviation:", TotRmsAbvGrd_Stdv)
# Out:
#  Mean : 6.5178
#  Median : 6.0
#  Standard Deviation: 1.6254

# %% [markdown]
# In the cell below, interpret the above information.

# %% [markdown]
# ### Data Finding Interpretation
# - **Mean** , The mean reveals that, on average, there are 6.5 rooms above grade. This reveals that, in Ames the majority of houses have 6 to 7 rooms.
# - **Median** , A median of 6 reveals that, half of the houses have 6 or more rooms above grade, while the other hald has 6 or lower rooms.
# - **Standard Deviation** , The standard deviation indicates that the houses in Ames have a moderate variation of 1.6 rooms from the mean. This implies that the houses above grade in Ames vary from approximately 5 to 8.
#
# **Additional Interpretation** The mean is slightly higher than the median, indicating that the data might be slightly skewed to the right. that is more houses are more than 6 rooms above grade

# %%
# df.describe()
# df.head()
# # Assessment - Visual, Programit
# df.info()
# df.tail()
# df.describe(include  = 'all')
# df.nunique()

# %% [markdown]
# ### Overall Condition
#
# In the cell below, produce a histogram for `OverallCond`.

# %%
# Histogram for Total Rooms Above Grade
#Filters data to only display Salesprice column
Overall_Condition = df.loc[:, 'OverallCond'] 
#Plot the histogram
plt.hist(Overall_Condition, bins= 15, edgecolor = 'black')
plt.xlabel('Overall Condition')
plt.ylabel('Frequency of Values')
plt.title('Distribution of Overall_Condition')
plt.show()

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# The below code computes the mean. median and standard deviation of Overall condition, rounds off the values to three decimal places and prints out the values.

# Overall Condition Mean
Overall_Condition_mean = round(Overall_Condition.mean(),3) 
# Salesprice median
Overall_Condition_median = round(Overall_Condition.median(),3)
# SalesPrice Standard deviation
Overall_Condition_Stdv = round(Overall_Condition.std(),3)
# Prints out the results
print(" Mean :", Overall_Condition_mean)
print(" Median :", Overall_Condition_median)
print(" Standard Deviation:", Overall_Condition_Stdv)
# Out:
#  Mean : 5.575
#  Median : 5.0
#  Standard Deviation: 1.113

# %% [markdown]
# In the cell below, interpret the above information.

# %% [markdown]
# ### Data Finding Interpretation
# - **Mean** , The overall condition of houses in Ames are rated at 5.575. assuming a scale of 1 to 10. We can interprate that the overall condition of houses in Ames is above average rating.
# - **Median** , An overall median of 5 indicates that half of the houses overall condition is above 5.0 and the remaining is below 5.0.
# - **Standard Deviation** , The overall condition has a small variation of the mean, indicating that most houses fall within a range of +- 1.113.
#
# **Additional Interpretation** The mean of the overall condition is greater than the median indicating that there is a small number of houses with overall condition greater than 5.
#
# """

# %% [markdown]
# ## 3. Explore Differences between Subsets
#
# As you might have noted in the previous step, the overall condition of the house seems like we should treat it as more of a categorical variable, rather than a numeric variable.
#
# One useful way to explore a categorical variable is to create subsets of the full dataset based on that categorical variable, then plot their distributions based on some other variable. Since this dataset is traditionally used for predicting the sale price of a house, let's use `SalePrice` as that other variable.
#
# In the cell below, create three variables, each of which represents a record-wise subset of `df` (meaning, it has the same columns as `df`, but only some of the rows).
#
# * `below_average_condition`: home sales where the overall condition was less than 5
# * `average_condition`: home sales where the overall condition was exactly 5
# * `above_average_condition`: home sales where the overall condition was greater than 5

# %%
# Home sales where the overall condition was less than 5 
below_average_condition = df.loc[df['OverallCond']<5] 
# Home sales where the overall condition was exactly 5 
average_condition = df.loc[df['OverallCond']== 5]
# Home sales where the overall condition was greater than 5
above_average_condition = df[df['OverallCond'] > 5]
# Visual Assessment.
display(below_average_condition.sample(2))
display(average_condition.sample(2))
display(above_average_condition.sample(2))
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1405          50       RL         60.0    10410   Pave  Grvl      Reg
# 111           50       RL         75.0     9525   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1405         Lvl    AllPub    Corner  ...        0    NaN  MnPrv         NaN
# 111          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1405       0      1    2006        WD         Family     105000
# 111        0     10    2006        WD         Normal     136900
#
# [2 rows x 80 columns]
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 777          20       RL         86.0    11210   Pave   NaN      IR1
# 701          20       RL         85.0    14331   Pave   NaN      Reg
#
# ...

# %% [markdown]
# The following code checks that you created the subsets correctly:

# %%
# Run this cell without changes
# Check that all of them still have 80 columns
assert below_average_condition.shape[1] == 80
assert average_condition.shape[1] == 80
assert above_average_condition.shape[1] == 80

# Check the numbers of rows of each subset
assert below_average_condition.shape[0] == 88
assert average_condition.shape[0] == 821
assert above_average_condition.shape[0] == 551

# %% [markdown]
# The following code will produce a plot of the distributions of sale price for each of these subsets:

# %%
# df['SalePrice'].plot(kind='hist', bins=15)

# %%
# Run this cell without changes

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Create custom bins so all are on the same scale
bins = range(df["SalePrice"].min(), df["SalePrice"].max(), int(df["SalePrice"].median()) // 20)

# Plot three histograms, with reduced opacity (alpha) so we
# can see them overlapping
ax.hist(
    x=above_average_condition["SalePrice"],
    label="above average condition",
    bins=bins,
    color="cyan",
    alpha=0.5
)
ax.hist(
    x=average_condition["SalePrice"],
    label="average condition",
    bins=bins,
    color="gray",
    alpha=0.3
)
ax.hist(
    x=below_average_condition["SalePrice"],
    label="below average condition",
    bins=bins,
    color="yellow",
    alpha=0.5
)

# Customize labels
ax.set_title("Distributions of Sale Price Grouped by Condition")
ax.set_xlabel("Sale Price")
ax.set_ylabel("Number of Houses")
ax.legend();

# %% [markdown]
# Interpret the plot above. What does it tell us about these overall condition categories, and the relationship between overall condition and sale price? Is there anything surprising?

# %% [markdown]
# ## Interpretation
# - The plot reveals that the overall condition of houses in Ames is an important factor that influence sales. This is because, the majority of sales are attributed to houses that have average condition and those above average.
# - We also have houses in average condition that are at a high sale price and houses with above average condition that have lower prices. This indicates that, other than the overall condition of houses, there are other factors that contribute to a successful home sale in Ames.

# %% [markdown]
# ## 4. Explore Correlations
#
# To understand more about what features of these homes lead to higher sale prices, let's look at some correlations. We'll return to using the full `df`, rather than the subsets.
#
# In the cell below, print out both the name of the column and the Pearson correlation for the column that is ***most positively correlated*** with `SalePrice` (other than `SalePrice`, which is perfectly correlated with itself).
#
# We'll only check the correlations with some kind of numeric data type.
#
# You can import additional libraries, although it is possible to do this just using pandas.

# %%
# Generating the name of column and pearson correlation of column that is most positively correlated with saleprice
saleprice_corr = df.corr()['SalePrice'].drop('SalePrice')
most_positive_corr_column = saleprice_corr.idxmax()  
most_positive_corr_value = saleprice_corr.max() 
most_positive_corr_column, round(most_positive_corr_value,6)
# Out:
# C:\Users\Mueni.Pauline\AppData\Local\Temp\ipykernel_14344\766321579.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   saleprice_corr = df.corr()['SalePrice'].drop('SalePrice')
# ('OverallQual', 0.790982)

# %% [markdown]
# Now, find the ***most negatively correlated*** column:

# %%
# Generating name and correlation of the most negatively correlated column with salesprice
most_negative_corr_column = saleprice_corr.idxmin()  
most_negative_corr_value = saleprice_corr.min()
most_negative_corr_column, round(most_positive_corr_value,6)
# Out:
# ('KitchenAbvGr', 0.790982)

# %%
import seaborn as sns
sns.heatmap(df.corr())
# Out:
# C:\Users\Mueni.Pauline\AppData\Local\Temp\ipykernel_14344\2249596087.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# Once you have your answer, edit the code below so that it produces a box plot of the relevant columns.

# %%
# Replace None with appropriate code
import seaborn as sns
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15,5))

# Plot distribution of column with highest correlation
sns.boxplot(
    x=df["OverallQual"],
    y=df["SalePrice"],
    ax=ax1
)
# Plot distribution of column with most negative correlation
sns.boxplot(
    x=df["KitchenAbvGr"],
    y=df["SalePrice"],
    ax=ax2
)

# Customize labels
ax1.set_title("Overall Quality boxplot against Sale Price")
ax1.set_xlabel("Overall Quality")
ax1.set_ylabel("Sale Price")
ax2.set_title("Distribution of Kitchen Above Grade against Sale Price")
ax2.set_xlabel("Kitchen Above Grade")
ax2.set_ylabel("Sale Price");

# %% [markdown]
# Interpret the results below. Consult `data/data_description.txt` as needed.

# %%
# Replace None with appropriate text
"""
None
"""

# %% [markdown]
# ## 5. Engineer and Explore a New Feature
#
# Here the code is written for you, all you need to do is interpret it.
#
# We note that the data spans across several years of sales:

# %% [markdown]
# ### Interpretation
#
# - The below code computes the number of houses sold per year. For instance, 2009 had the leading number of sales with 338 houses sold, followed by year 2007 with 329 sold houses, while the year with the least sales was 2010 with 175 houses.

# %%
# Run this cell without changes
df["YrSold"].value_counts().sort_index()
# Out:
# 2006    314
# 2007    329
# 2008    304
# 2009    338
# 2010    175
# Name: YrSold, dtype: int64

# %% [markdown]
# Maybe we can learn something interesting from the age of the home when it was sold. This uses information from the `YrBuilt` and `YrSold` columns, but represents a truly distinct feature.

# %%
# Run this cell without changes

# Make a new column, Age
df["Age"] = df["YrSold"] - df["YearBuilt"]

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Plot Age vs. SalePrice
ax.scatter(df["Age"], df["SalePrice"], alpha=0.3, color="green")
ax.set_title("Home Age vs. Sale Price")
ax.set_xlabel("Age of Home at Time of Sale")
ax.set_ylabel("Sale Price");

# %% [markdown]
# Interpret this plot below:

# %% [markdown]
# # Interpretation
#
# - The scatter plot shows the distribution of house sales based on their age (year built and year sold).
# - Results from the scatter plot shows that the majority of sales are concetrated from 0 to 60 years,
# with the price decreasing with age of the house.
# - This implies that there is a significant positive correlation between the age of the home at the time of sale and the sale price.

# %% [markdown]
# ## Summary
#
# Congratulations, you've completed an exploratory data analysis of a popular dataset. You saw how to inspect the distributions of individual columns, subsets of columns, correlations, and new engineered features.
